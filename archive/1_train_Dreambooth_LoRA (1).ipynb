# %% [markdown]
# ## Personalization Workshop - Part 1:
# ## Fine-tuning Stable Diffusion XL with DreamBooth and LoRA
#
# In this notebook, we'll see an example of how to fine-tune [Stable Diffusion XL (SDXL)](https://huggingface.co/docs/diffusers/main/en/api/pipelines/stable_diffusion/stable_diffusion_xl) with [DreamBooth](https://huggingface.co/docs/diffusers/main/en/training/dreambooth) and [LoRA](https://huggingface.co/docs/diffusers/main/en/training/lora).
#
# Note: SDXL consists of a much larger UNet and two text encoders that make the cross-attention context quite larger than the previous Stable Diffusion checkpoints.
# So, in order to train on a T4 GPU, we'll need to make use of several tricks such as gradient checkpointing, mixed-precision, and 8-bit Adam. If these don't ring a bell, no worries at all! we'll walk through them all

# %% [markdown]
# ## Setup 🪓

# %% [markdown]
# Create an account on the Hugging Face Hub 🤗 If you haven't done so yet, you can do so here: https://huggingface.co/join

# %%
# Check the GPU
# !nvidia-smi
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Install dependencies.
# !pip install bitsandbytes transformers torchao==0.16.0  accelerate peft -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 42.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 9.8 MB/s eta 0:00:00

# %% [markdown]
# Make sure to install `diffusers` from `main`.

# %%
# !pip install git+https://github.com/huggingface/diffusers.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.1/509.1 kB 10.6 MB/s eta 0:00:00
#   Building wheel for diffusers (pyproject.toml) ... done

# %% [markdown]
# Download diffusers SDXL DreamBooth training script.

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Out:
# --2026-05-18 20:28:33--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86933 (85K) [text/plain]
# Saving to: ‘train_dreambooth_lora_sdxl.py’
#
# train_dreambooth_lo 100%[===================>]  84.90K  --.-KB/s    in 0.009s
#
# 2026-05-18 20:28:34 (8.94 MB/s) - ‘train_dreambooth_lora_sdxl.py’ saved [86933/86933]

# %% [markdown]
# ## Dataset 🐶

# %% [markdown]
# **Let's get our training data!**
# For this example, we'll download some images from the hub
#
# If you already have a dataset on the hub you wish to use, you can skip this part and go straight to: "Prep for
# training 💻" section, where you'll simply specify the dataset name.
#
# If your images are saved locally, and/or you want to add BLIP generated captions,
# pick option 1 or 2 below.

# %% [markdown]
# **Option 2:** download example images from the hub:

# %%
from huggingface_hub import snapshot_download

local_dir = "./dog/"
snapshot_download(
    "diffusers/dog-example",
    local_dir=local_dir, repo_type="dataset",
    ignore_patterns=".gitattributes",
)
# Out:
# Running cells with 'Python 3.12.13' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Preview the images:

# %%
from PIL import Image

def image_grid(imgs, rows, cols, resize=256):

    if resize is not None:
        imgs = [img.resize((resize, resize)) for img in imgs]
    w, h = imgs[0].size
    grid = Image.new("RGB", size=(cols * w, rows * h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i % cols * w, i // cols * h))
    return grid

# %%
import glob

# change path to display images from your local dir
img_paths = "./dog/*.jpeg"
imgs = [Image.open(path) for path in glob.glob(img_paths)]
print(imgs[0].__class__)
num_imgs_to_preview = 5
image_grid(imgs[:num_imgs_to_preview], 1, num_imgs_to_preview)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.Image.Image image mode=RGB size=1280x256>

# %% [markdown]
# ### Generate custom captions with BLIP
# Load BLIP to auto caption your images:

# %%
import requests
from transformers import AutoProcessor, BlipForConditionalGeneration
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

# load the processor and the captioning model
blip_processor = AutoProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base",torch_dtype=torch.float16).to(device)

# captioning utility
def caption_images(input_image):
    inputs = blip_processor(images=input_image, return_tensors="pt").to(device, torch.float16)
    pixel_values = inputs.pixel_values

    generated_ids = blip_model.generate(pixel_values=pixel_values, max_length=50)
    generated_caption = blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return generated_caption
# Out:
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# The image processor of type `BlipImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie text_decoder.cls.predictions.bias to text_decoder.cls.predictions.decoder.bias, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie text_decoder.bert.embeddings.word_embeddings.weight to text_decoder.cls.predictions.decoder.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# BlipForConditionalGeneration LOAD REPORT from: Salesforce/blip-image-captioning-base
# Key                                       | Status     |  |
# ------------------------------------------+------------+--+-
# text_decoder.bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
import glob
from PIL import Image

# create a list of (Pil.Image, path) pairs
local_dir = "./dog/"
imgs_and_paths = [(path,Image.open(path)) for path in glob.glob(f"{local_dir}*.jpeg")]

# %% [markdown]
# Now let's add the concept token identifier (e.g. TOK) to each caption using a caption prefix.
# Feel free to change the prefix according to the concept you're training on!
# - for this example we can use "a photo of TOK," other options include:
#     - For styles - "In the style of TOK"
#     - For faces - "photo of a TOK person"
# - You can add additional identifiers to the prefix that can help steer the model in the right direction.
# -- e.g. for this example, instead of "a photo of TOK" we can use "a photo of TOK dog" / "a photo of TOK corgi dog"

# %%
import json

caption_prefix = "a photo of TOK dog, " #@param
with open(f'{local_dir}metadata.jsonl', 'w') as outfile:
  for img in imgs_and_paths:
      caption = caption_prefix + caption_images(img[1]).split("\n")[0]
      entry = {"file_name":img[0].split("/")[-1], "prompt": caption}
      json.dump(entry, outfile)
      outfile.write('\n')

# %% [markdown]
# Free some memory:

# %%
import gc

# delete the BLIP pipelines and free up some memory
del blip_processor, blip_model
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Prep for training 💻

# %% [markdown]
# Initialize `accelerate`:

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %% [markdown]
# ### Log into your Hugging Face account
# Pass [your **write** access token](https://huggingface.co/settings/tokens) so that we can push the trained checkpoints to the Hugging Face Hub:

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Train! 🔬

# %% [markdown]
# #### Set Hyperparameters ⚡
# To ensure we can DreamBooth with LoRA on a heavy pipeline like Stable Diffusion XL, we're using:
#
# * Gradient checkpointing (`--gradient_accumulation_steps`)
# * 8-bit Adam (`--use_8bit_adam`)
# * Mixed-precision training (`--mixed-precision="fp16"`)

# %% [markdown]
# ### Launch training 🚀🚀🚀

# %% [markdown]
# To allow for custom captions we need to install the `datasets` library, you can skip that if you want to train solely
#  with `--instance_prompt`.
# In that case, specify `--instance_data_dir` instead of `--dataset_name`

# %%
# !pip install datasets -q

# %% [markdown]
#  - Use `--output_dir` to specify your LoRA model repository name!
#  - Use `--caption_column` to specify name of the cpation column in your dataset. In this example we used "prompt" to
#  save our captions in the
#  metadata file, change this according to your needs.

# %%
#!/usr/bin/env bash
# !accelerate launch train_dreambooth_lora_sdxl.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0" \
  --pretrained_vae_model_name_or_path="madebyollin/sdxl-vae-fp16-fix" \
  --dataset_name="dog" \
  --output_dir="corgy_dog_LoRA" \
  --caption_column="prompt"\
  --mixed_precision="fp16" \
  --instance_prompt="a photo of TOK dog" \
  --resolution=1024 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=3 \
  --gradient_checkpointing \
  --learning_rate=1e-4 \
  --snr_gamma=5.0 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --max_train_steps=500 \
  --checkpointing_steps=717 \
  --seed="0"
# Out:
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 05/18/2026 20:31:01 - INFO - __main__ - [RANK 0] Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# 05/18/2026 20:31:01 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/config.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:01 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/config.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:01 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:01 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:01 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 737/737 [00:00<00:00, 3.15MB/s]
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Fvocab.json "HTTP/1.1 200 OK"
# vocab.json: 1.06MB [00:00, 7.58MB/s]
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# 05/18/2026 20:31:02 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Fmerges.txt "HTTP/1.1 200 OK"
# merges.txt: 525kB [00:00, 41.5MB/s]
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/tokenizer.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/added_tokens.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 2.80MB/s]
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer/chat_template.jinja "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/config.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/config.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:03 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer_2%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer_2%2Ftokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json: 100% 725/725 [00:00<00:00, 3.31MB/s]
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/vocab.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer_2%2Fvocab.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/merges.txt "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer_2%2Fmerges.txt "HTTP/1.1 200 OK"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/tokenizer.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/added_tokens.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:04 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer_2%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/tokenizer_2%2Fspecial_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json: 100% 460/460 [00:00<00:00, 2.69MB/s]
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/tokenizer_2/chat_template.jinja "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 565/565 [00:00<00:00, 3.92MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder_2/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder_2%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder_2%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 100% 575/575 [00:00<00:00, 3.18MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/model_index.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:05 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/model_index.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/model_index.json "HTTP/1.1 200 OK"
# model_index.json: 100% 609/609 [00:00<00:00, 3.91MB/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/scheduler%2Fscheduler_config.json "HTTP/1.1 200 OK"
# scheduler_config.json: 100% 479/479 [00:00<00:00, 2.47MB/s]
# {'variance_type', 'thresholding', 'dynamic_thresholding_ratio', 'clip_sample_range', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder/adapter_config.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder/model.safetensors "HTTP/1.1 302 Found"
# 05/18/2026 20:31:06 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/xet-read-token/462165984030d82259a11f4367a4eed129e94a7b "HTTP/1.1 200 OK"
# text_encoder/model.safetensors: 100% 492M/492M [00:11<00:00, 44.7MB/s]
# Loading weights: 100% 196/196 [00:00<00:00, 612.58it/s, Materializing param=text_model.final_layer_norm.weight]
# 05/18/2026 20:31:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder_2/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder_2%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder_2/adapter_config.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:31:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder_2/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:31:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/text_encoder_2%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:31:18 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/text_encoder_2/model.safetensors "HTTP/1.1 302 Found"
# text_encoder_2/model.safetensors: 100% 2.78G/2.78G [02:22<00:00, 19.5MB/s]
# Loading weights: 100% 517/517 [00:08<00:00, 60.14it/s, Materializing param=text_projection.weight]
# 05/18/2026 20:33:50 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:33:50 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/madebyollin/sdxl-vae-fp16-fix/207b116dae70ace3637169f1ddd2434b91b3a8cd/config.json "HTTP/1.1 200 OK"
# 05/18/2026 20:33:50 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/madebyollin/sdxl-vae-fp16-fix/207b116dae70ace3637169f1ddd2434b91b3a8cd/config.json "HTTP/1.1 200 OK"
# config.json: 100% 631/631 [00:00<00:00, 3.47MB/s]
# 05/18/2026 20:33:50 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/207b116dae70ace3637169f1ddd2434b91b3a8cd/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:33:50 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/207b116dae70ace3637169f1ddd2434b91b3a8cd/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# 05/18/2026 20:33:50 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/madebyollin/sdxl-vae-fp16-fix/xet-read-token/207b116dae70ace3637169f1ddd2434b91b3a8cd "HTTP/1.1 200 OK"
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:05<00:00, 61.8MB/s]
# {'use_quant_conv', 'use_post_quant_conv', 'mid_block_add_attention', 'shift_factor', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at madebyollin/sdxl-vae-fp16-fix.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 05/18/2026 20:33:56 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/unet/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 20:33:56 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/unet%2Fconfig.json "HTTP/1.1 200 OK"
# 05/18/2026 20:33:56 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/unet%2Fconfig.json "HTTP/1.1 200 OK"
# config.json: 1.68kB [00:00, 412kB/s]
# 05/18/2026 20:33:56 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/462165984030d82259a11f4367a4eed129e94a7b/unet/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# 05/18/2026 20:33:56 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/462165984030d82259a11f4367a4eed129e94a7b/unet/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# unet/diffusion_pytorch_model.safetensors: 100% 10.3G/10.3G [09:54<00:00, 17.3MB/s]
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at stabilityai/stable-diffusion-xl-base-1.0.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# 05/18/2026 20:44:37 - INFO - datasets - TensorFlow version 2.20.0 available.
# 05/18/2026 20:44:37 - INFO - datasets - JAX version 0.7.2 available.
# Generating train split: 5 examples [00:00, 132.48 examples/s]
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0] ***** Running training *****
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Num examples = 5
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Num batches each epoch = 5
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Num Epochs = 250
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Instantaneous batch size per device = 1
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Total train batch size (w. parallel, distributed & accumulation) = 3
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Gradient Accumulation steps = 3
# 05/18/2026 20:44:48 - INFO - __main__ - [RANK 0]   Total optimization steps = 500
# Steps: 100% 500/500 [1:05:58<00:00,  7.66s/it, loss=0.00527, lr=0.0001]Model weights saved in corgy_dog_LoRA/pytorch_lora_weights.safetensors
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# 05/18/2026 21:50:47 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 21:50:47 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/madebyollin/sdxl-vae-fp16-fix/207b116dae70ace3637169f1ddd2434b91b3a8cd/config.json "HTTP/1.1 200 OK"
# 05/18/2026 21:50:47 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/207b116dae70ace3637169f1ddd2434b91b3a8cd/diffusion_pytorch_model.safetensors.index.json "HTTP/1.1 404 Not Found"
# Instantiating AutoencoderKL model under default dtype torch.float16.
# {'use_quant_conv', 'use_post_quant_conv', 'mid_block_add_attention', 'shift_factor', 'latents_mean', 'latents_std'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at madebyollin/sdxl-vae-fp16-fix.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# 05/18/2026 21:50:49 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0 "HTTP/1.1 200 OK"
# 05/18/2026 21:50:49 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/model_index.json "HTTP/1.1 307 Temporary Redirect"
# 05/18/2026 21:50:49 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/stabilityai/stable-diffusion-xl-base-1.0/462165984030d82259a11f4367a4eed129e94a7b/model_index.json "HTTP/1.1 200 OK"
# 05/18/2026 21:50:49 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/revision/main "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
#
# Fetching 17 files:   0% 0/17 [00:00<?, ?it/s]05/18/2026 21:50:49 - INFO - httpx - HTTP Request: HEAD https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/462165984030d82259a11f4367a4eed129e94a7b/vae_1_0/diffusion_pytorch_model.safetensors "HTTP/1.1 302 Found"
# 05/18/2026 21:50:49 - INFO - httpx - HTTP Request: GET https://huggingface.co/api/models/stabilityai/stable-diffusion-xl-base-1.0/xet-read-token/462165984030d82259a11f4367a4eed129e94a7b "HTTP/1.1 200 OK"
#
# Downloading (incomplete total...):   0% 0.00/335M [00:00<?, ?B/s]
# Downloading (incomplete total...):   0% 0.00/335M [00:00<?, ?B/s]
# Downloading (incomplete total...):   0% 0.00/335M [00:00<?, ?B/s]
# Downloading (incomplete total...):   0% 0.00/335M [00:00<?, ?B/s]
# Downloading (incomplete total...):   0% 0.00/335M [00:01<?, ?B/s]
# Downloading (incomplete total...):   0% 0.00/335M [00:01<?, ?B/s]
# Downloading (incomplete total...):   0% 0.00/335M [00:01<?, ?B/s]
# Downloading (incomplete total...):  20% 67.1M/335M [00:01<00:00, 352MB/s]
# Downloading (incomplete total...):  40% 134M/335M [00:04<00:04, 45.0MB/s]
# Downloading (incomplete total...): 100% 335M/335M [00:14<00:00, 23.4MB/s]
#
# Fetching 17 files: 100% 17/17 [00:14<00:00,  1.20it/s]
#
# Download complete: 100% 335M/335M [00:14<00:00, 23.4MB/s]                {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Instantiating UNet2DConditionModel model under default dtype torch.float16.
# {'attention_type', 'reverse_transformer_layers_per_block', 'dropout'} was not found in config. Values will be initialized to default values.
# Download complete: 100% 335M/335M [00:14<00:00, 23.5MB/s]
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-xl-base-1.0/snapshots/462165984030d82259a11f4367a4eed129e94a7b/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
#
# Loading pipeline components...:  14% 1/7 [00:47<04:42, 47.03s/it]Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
#
# Loading pipeline components...:  29% 2/7 [00:47<01:37, 19.47s/it]{'use_beta_sigmas', 'final_sigmas_type', 'timestep_type', 'sigma_max', 'sigma_min', 'use_exponential_sigmas', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
#
# Loading pipeline components...:  43% 3/7 [00:47<00:42, 10.67s/it]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 6423.13it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 2920.82it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 398.81it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 381.09it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   2% 3/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   2% 3/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2% 3/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.bias]
# Loading weights:   2% 4/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   2% 4/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm1.weight]
# Loading weights:   3% 5/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3% 5/196 [00:01<01:12,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.bias]
# Loading weights:   3% 6/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   3% 6/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.layer_norm2.weight]
# Loading weights:   4% 7/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   4% 7/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.bias]
# Loading weights:   4% 8/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   4% 8/196 [00:01<01:11,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc1.weight]
# Loading weights:   5% 9/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   5% 9/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.bias]
# Loading weights:   5% 10/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   5% 10/196 [00:01<01:10,  2.65it/s, Materializing param=text_model.encoder.layers.0.mlp.fc2.weight]
# Loading weights:   6% 11/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   6% 11/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.bias]
# Loading weights:   6% 12/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   6% 12/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.k_proj.weight]
# Loading weights:   7% 13/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   7% 13/196 [00:01<01:09,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.bias]
# Loading weights:   7% 14/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   7% 14/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.out_proj.weight]
# Loading weights:   8% 15/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   8% 15/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.bias]
# Loading weights:   8% 16/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   8% 16/196 [00:01<01:08,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.q_proj.weight]
# Loading weights:   9% 17/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   9% 17/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.bias]
# Loading weights:   9% 18/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:   9% 18/196 [00:01<01:07,  2.65it/s, Materializing param=text_model.encoder.layers.0.self_attn.v_proj.weight]
# Loading weights:  10% 19/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:  10% 19/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.bias]
# Loading weights:  10% 20/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:  10% 20/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm1.weight]
# Loading weights:  11% 21/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:  11% 21/196 [00:01<01:06,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.bias]
# Loading weights:  11% 22/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:  11% 22/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.layer_norm2.weight]
# Loading weights:  12% 23/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:  12% 23/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.bias]
# Loading weights:  12% 24/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:  12% 24/196 [00:01<01:05,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc1.weight]
# Loading weights:  13% 25/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:  13% 25/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.bias]
# Loading weights:  13% 26/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:  13% 26/196 [00:01<01:04,  2.65it/s, Materializing param=text_model.encoder.layers.1.mlp.fc2.weight]
# Loading weights:  14% 27/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:  14% 27/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.bias]
# Loading weights:  14% 28/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:  14% 28/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.k_proj.weight]
# Loading weights:  15% 29/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:  15% 29/196 [00:01<01:03,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.bias]
# Loading weights:  15% 30/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:  15% 30/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.out_proj.weight]
# Loading weights:  16% 31/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:  16% 31/196 [00:01<01:02,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.bias]
# Loading weights:  16% 32/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  16% 32/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.q_proj.weight]
# Loading weights:  17% 33/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  17% 33/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.bias]
# Loading weights:  17% 34/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  17% 34/196 [00:01<01:01,  2.65it/s, Materializing param=text_model.encoder.layers.1.self_attn.v_proj.weight]
# Loading weights:  18% 35/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  18% 35/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.bias]
# Loading weights:  18% 36/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  18% 36/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm1.weight]
# Loading weights:  19% 37/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  19% 37/196 [00:01<01:00,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.bias]
# Loading weights:  19% 38/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  19% 38/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.layer_norm2.weight]
# Loading weights:  20% 39/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  20% 39/196 [00:01<00:59,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.bias]
# Loading weights:  20% 40/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  20% 40/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc1.weight]
# Loading weights:  21% 41/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  21% 41/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.bias]
# Loading weights:  21% 42/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  21% 42/196 [00:01<00:58,  2.65it/s, Materializing param=text_model.encoder.layers.2.mlp.fc2.weight]
# Loading weights:  22% 43/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  22% 43/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.bias]
# Loading weights:  22% 44/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  22% 44/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.k_proj.weight]
# Loading weights:  23% 45/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  23% 45/196 [00:01<00:57,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.bias]
# Loading weights:  23% 46/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  23% 46/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.out_proj.weight]
# Loading weights:  24% 47/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  24% 47/196 [00:01<00:56,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.bias]
# Loading weights:  24% 48/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  24% 48/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.q_proj.weight]
# Loading weights:  25% 49/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  25% 49/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.bias]
# Loading weights:  26% 50/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  26% 50/196 [00:01<00:55,  2.65it/s, Materializing param=text_model.encoder.layers.2.self_attn.v_proj.weight]
# Loading weights:  26% 51/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  26% 51/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.bias]
# Loading weights:  27% 52/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  27% 52/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm1.weight]
# Loading weights:  27% 53/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  27% 53/196 [00:01<00:54,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.bias]
# Loading weights:  28% 54/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  28% 54/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.layer_norm2.weight]
# Loading weights:  28% 55/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  28% 55/196 [00:01<00:53,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.bias]
# Loading weights:  29% 56/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  29% 56/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc1.weight]
# Loading weights:  29% 57/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  29% 57/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.bias]
# Loading weights:  30% 58/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  30% 58/196 [00:01<00:52,  2.65it/s, Materializing param=text_model.encoder.layers.3.mlp.fc2.weight]
# Loading weights:  30% 59/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  30% 59/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.bias]
# Loading weights:  31% 60/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  31% 60/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.k_proj.weight]
# Loading weights:  31% 61/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  31% 61/196 [00:01<00:51,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.bias]
# Loading weights:  32% 62/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  32% 62/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.out_proj.weight]
# Loading weights:  32% 63/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  32% 63/196 [00:01<00:50,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.bias]
# Loading weights:  33% 64/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  33% 64/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.q_proj.weight]
# Loading weights:  33% 65/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  33% 65/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.bias]
# Loading weights:  34% 66/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  34% 66/196 [00:01<00:49,  2.65it/s, Materializing param=text_model.encoder.layers.3.self_attn.v_proj.weight]
# Loading weights:  34% 67/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  34% 67/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.bias]
# Loading weights:  35% 68/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  35% 68/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm1.weight]
# Loading weights:  35% 69/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  35% 69/196 [00:01<00:48,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.bias]
# Loading weights:  36% 70/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  36% 70/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.layer_norm2.weight]
# Loading weights:  36% 71/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  36% 71/196 [00:01<00:47,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.bias]
# Loading weights:  37% 72/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  37% 72/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc1.weight]
# Loading weights:  37% 73/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  37% 73/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.bias]
# Loading weights:  38% 74/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  38% 74/196 [00:01<00:46,  2.65it/s, Materializing param=text_model.encoder.layers.4.mlp.fc2.weight]
# Loading weights:  38% 75/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  38% 75/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.bias]
# Loading weights:  39% 76/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  39% 76/196 [00:01<00:45,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.k_proj.weight]
# Loading weights:  39% 77/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  39% 77/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.bias]
# Loading weights:  40% 78/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  40% 78/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.out_proj.weight]
# Loading weights:  40% 79/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  40% 79/196 [00:01<00:44,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.bias]
# Loading weights:  41% 80/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  41% 80/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.q_proj.weight]
# Loading weights:  41% 81/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  41% 81/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.bias]
# Loading weights:  42% 82/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
# Loading weights:  42% 82/196 [00:01<00:43,  2.65it/s, Materializing param=text_model.encoder.layers.4.self_attn.v_proj.weight]
# Loading weights:  42% 83/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
# Loading weights:  42% 83/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.bias]
# Loading weights:  43% 84/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43% 84/196 [00:01<00:42,  2.65it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43% 85/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.layer_norm1.weight]
# Loading weights:  43% 85/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
# Loading weights:  43% 85/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.bias]
# Loading weights:  44% 86/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
# Loading weights:  44% 86/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.layer_norm2.weight]
# Loading weights:  44% 87/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
# Loading weights:  44% 87/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.bias]
# Loading weights:  45% 88/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
# Loading weights:  45% 88/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc1.weight]
# Loading weights:  45% 89/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
# Loading weights:  45% 89/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.bias]
# Loading weights:  46% 90/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
# Loading weights:  46% 90/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.mlp.fc2.weight]
# Loading weights:  46% 91/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
# Loading weights:  46% 91/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.bias]
# Loading weights:  47% 92/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
# Loading weights:  47% 92/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.self_attn.k_proj.weight]
# Loading weights:  47% 93/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
# Loading weights:  47% 93/196 [00:01<00:01, 93.25it/s, Materializing param=text_model.encoder.layers.5.self_attn.out_proj.bias]
# ...
# Loading weights:  89% 462/517 [00:10<00:01, 47.96it/s, Materializing param=text_model.encoder.layers.28.self_attn.out_proj.weight]
# Loading weights:  89% 462/517 [00:10<00:01, 47.96it/s, Materializing param=text_model.encoder.layers.28.self_attn.out_proj.weight]
# Loading weights:  90% 463/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.out_proj.weight]
# Loading weights:  90% 463/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.q_proj.bias]
# Loading weights:  90% 463/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.q_proj.bias]
# Loading weights:  90% 464/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.q_proj.weight]
# Loading weights:  90% 464/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.q_proj.weight]
# Loading weights:  90% 465/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.v_proj.bias]
# Loading weights:  90% 465/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.v_proj.bias]
# Loading weights:  90% 466/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.v_proj.weight]
# Loading weights:  90% 466/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.28.self_attn.v_proj.weight]
# Loading weights:  90% 467/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.bias]
# Loading weights:  90% 467/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.bias]
# Loading weights:  91% 468/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.weight]
# Loading weights:  91% 468/517 [00:10<00:01, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm1.weight]
# Loading weights:  91% 469/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.bias]
# Loading weights:  91% 469/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.bias]
# Loading weights:  91% 470/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.weight]
# Loading weights:  91% 470/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.layer_norm2.weight]
# Loading weights:  91% 471/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.bias]
# Loading weights:  91% 471/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.bias]
# Loading weights:  91% 472/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.weight]
# Loading weights:  91% 472/517 [00:10<00:00, 48.93it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.weight]
# Loading weights:  91% 473/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.mlp.fc1.weight]
# Loading weights:  91% 473/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.bias]
# Loading weights:  91% 473/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.bias]
# Loading weights:  92% 474/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.weight]
# Loading weights:  92% 474/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.mlp.fc2.weight]
# Loading weights:  92% 475/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.bias]
# Loading weights:  92% 475/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.bias]
# Loading weights:  92% 476/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.weight]
# Loading weights:  92% 476/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.k_proj.weight]
# Loading weights:  92% 477/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.bias]
# Loading weights:  92% 477/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.bias]
# Loading weights:  92% 478/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.weight]
# Loading weights:  92% 478/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.out_proj.weight]
# Loading weights:  93% 479/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.bias]
# Loading weights:  93% 479/517 [00:11<00:00, 47.73it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.bias]
# Loading weights:  93% 480/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.bias]
# Loading weights:  93% 480/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.weight]
# Loading weights:  93% 480/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.q_proj.weight]
# Loading weights:  93% 481/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.bias]
# Loading weights:  93% 481/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.bias]
# Loading weights:  93% 482/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.weight]
# Loading weights:  93% 482/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.29.self_attn.v_proj.weight]
# Loading weights:  93% 483/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.bias]
# Loading weights:  93% 483/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.bias]
# Loading weights:  94% 484/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.weight]
# Loading weights:  94% 484/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm1.weight]
# Loading weights:  94% 485/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.bias]
# Loading weights:  94% 485/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.bias]
# Loading weights:  94% 486/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.weight]
# Loading weights:  94% 486/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.layer_norm2.weight]
# Loading weights:  94% 487/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.bias]
# Loading weights:  94% 487/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.bias]
# Loading weights:  94% 488/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.weight]
# Loading weights:  94% 488/517 [00:11<00:00, 52.04it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.weight]
# Loading weights:  95% 489/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.mlp.fc1.weight]
# Loading weights:  95% 489/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.bias]
# Loading weights:  95% 489/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.bias]
# Loading weights:  95% 490/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.weight]
# Loading weights:  95% 490/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.mlp.fc2.weight]
# Loading weights:  95% 491/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.bias]
# Loading weights:  95% 491/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.bias]
# Loading weights:  95% 492/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.weight]
# Loading weights:  95% 492/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.k_proj.weight]
# Loading weights:  95% 493/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.bias]
# Loading weights:  95% 493/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.bias]
# Loading weights:  96% 494/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.weight]
# Loading weights:  96% 494/517 [00:11<00:00, 46.86it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.weight]
# Loading weights:  96% 495/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.out_proj.weight]
# Loading weights:  96% 495/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.bias]
# Loading weights:  96% 495/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.bias]
# Loading weights:  96% 496/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.weight]
# Loading weights:  96% 496/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.q_proj.weight]
# Loading weights:  96% 497/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.bias]
# Loading weights:  96% 497/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.bias]
# Loading weights:  96% 498/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.weight]
# Loading weights:  96% 498/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.30.self_attn.v_proj.weight]
# Loading weights:  97% 499/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.bias]
# Loading weights:  97% 499/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.bias]
# Loading weights:  97% 500/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.weight]
# Loading weights:  97% 500/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm1.weight]
# Loading weights:  97% 501/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.bias]
# Loading weights:  97% 501/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.bias]
# Loading weights:  97% 502/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.weight]
# Loading weights:  97% 502/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.layer_norm2.weight]
# Loading weights:  97% 503/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.bias]
# Loading weights:  97% 503/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.bias]
# Loading weights:  97% 504/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.weight]
# Loading weights:  97% 504/517 [00:11<00:00, 48.71it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.weight]
# Loading weights:  98% 505/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.mlp.fc1.weight]
# Loading weights:  98% 505/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.bias]
# Loading weights:  98% 505/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.bias]
# Loading weights:  98% 506/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.weight]
# Loading weights:  98% 506/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.mlp.fc2.weight]
# Loading weights:  98% 507/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.bias]
# Loading weights:  98% 507/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.bias]
# Loading weights:  98% 508/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.weight]
# Loading weights:  98% 508/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.k_proj.weight]
# Loading weights:  98% 509/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.bias]
# Loading weights:  98% 509/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.bias]
# Loading weights:  99% 510/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.weight]
# Loading weights:  99% 510/517 [00:11<00:00, 47.29it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.weight]
# Loading weights:  99% 511/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.out_proj.weight]
# Loading weights:  99% 511/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.bias]
# Loading weights:  99% 511/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.bias]
# Loading weights:  99% 512/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.weight]
# Loading weights:  99% 512/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.q_proj.weight]
# Loading weights:  99% 513/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.bias]
# Loading weights:  99% 513/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.bias]
# Loading weights:  99% 514/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.weight]
# Loading weights:  99% 514/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.encoder.layers.31.self_attn.v_proj.weight]
# Loading weights: 100% 515/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.final_layer_norm.bias]
# Loading weights: 100% 515/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.final_layer_norm.bias]
# Loading weights: 100% 516/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.final_layer_norm.weight]
# Loading weights: 100% 516/517 [00:11<00:00, 49.50it/s, Materializing param=text_model.final_layer_norm.weight]
# Loading weights: 100% 517/517 [00:11<00:00, 49.50it/s, Materializing param=text_projection.weight]
# Loading weights: 100% 517/517 [00:11<00:00, 43.13it/s, Materializing param=text_projection.weight]
# Loaded text_encoder_2 as CLIPTextModelWithProjection from `text_encoder_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
#
# Loading pipeline components...: 100% 7/7 [01:01<00:00,  8.83s/it]
# Loading unet.
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# No LoRA keys associated to CLIPTextModelWithProjection found with the prefix='text_encoder_2'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModelWithProjection related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# Steps: 100% 500/500 [1:07:18<00:00,  8.08s/it, loss=0.00527, lr=0.0001]

# %% [markdown]
# ### Save your model to the hub and check it out 🔥

# %%
from huggingface_hub import whoami
from pathlib import Path
#@markdown make sure the `output_dir` you specify here is the same as the one used for training
output_dir = "corgy_dog_LoRA" #@param
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{output_dir}"

# %%
# @markdown Sometimes training finishes succesfuly (i.e. a **.safetensores** file with the LoRA weights saved properly to your local `output_dir`) but there's not enough RAM in the free tier to push the model to the hub 🙁
# @markdown
# @markdown To mitigate this, run this cell with your training arguments to make sure your model is uploaded! 🤗

# push to the hub🔥
from train_dreambooth_lora_sdxl import save_model_card
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id

# change the params below according to your training arguments
save_model_card(
    repo_id = repo_id,
    images=[],
    base_model="stabilityai/stable-diffusion-xl-base-1.0",
    train_text_encoder=False,
    instance_prompt="a photo of TOK dog",
    validation_prompt=None,
    repo_folder=output_dir,
    vae_path="madebyollin/sdxl-vae-fp16-fix",
    use_dora =False,
)

upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="End of training",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ..._lora_weights.safetensors:   0%|          | 94.1kB / 23.4MB
#   ...2401.ad51294e9ee8.15665.1:   2%|2         |  80.0B / 3.41kB
#   ...2401.ad51294e9ee8.15665.0:   2%|2         | 2.46kB /  104kB
# CommitInfo(commit_url='https://huggingface.co/TeddyVDobreva/corgy_dog_LoRA/commit/c8866c06356a338679954c1ac25b22bb844e7b16', commit_message='End of training', commit_description='', oid='c8866c06356a338679954c1ac25b22bb844e7b16', pr_url=None, repo_url=RepoUrl('https://huggingface.co/TeddyVDobreva/corgy_dog_LoRA', endpoint='https://huggingface.co', repo_type='model', repo_id='TeddyVDobreva/corgy_dog_LoRA'), pr_revision=None, pr_num=None)

# %%
from IPython.display import display, Markdown

link_to_model = f"https://huggingface.co/{repo_id}"
display(Markdown("### Your model has finished training.\nAccess it here: {}".format(link_to_model)))
# Out:
# ### Your model has finished training.
# Access it here: https://huggingface.co/TeddyVDobreva/corgy_dog_LoRA

# %% [markdown]
# Let's generate some images with it!

# %% [markdown]
# ## Inference 🐕

# %%
import torch
from diffusers import DiffusionPipeline, AutoencoderKL

vae = AutoencoderKL.from_pretrained("madebyollin/sdxl-vae-fp16-fix", torch_dtype=torch.float16)
pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    vae=vae,
    torch_dtype=torch.float16,
    variant="fp16",
    use_safetensors=True
)
pipe.load_lora_weights(repo_id)
_ = pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/517 [00:00<?, ?it/s]
# pytorch_lora_weights.safetensors:   0%|          | 0.00/23.4M [00:00<?, ?B/s]
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# No LoRA keys associated to CLIPTextModelWithProjection found with the prefix='text_encoder_2'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModelWithProjection related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new

# %%
prompt = "a photo of husky dog in a pool" # @param

image = pipe(prompt=prompt, num_inference_steps=25).images[0]
image
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>
